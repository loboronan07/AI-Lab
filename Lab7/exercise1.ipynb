# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
class Graph:
    def __init__(self):
        self.adjlist = dict()
        self.g = nx.Graph()
        
    def addedge(self, u, v, w):
        if u in self.adjlist:
            self.adjlist[u][v] = w
        else:
            self.adjlist[u] = {v:w}
            
        if v in self.adjlist:
            self.adjlist[v][u] = w
        else:
            self.adjlist[v] = {u:w}
            
        self.g.add_edge(u, v, wt=w)
        
    def visualize(self): 
        pos = nx.kamada_kawai_layout(self.g)
        nx.draw(self.g, pos=pos, with_labels=True, node_size=500, alpha=0.8)
        edge_labels = nx.get_edge_attributes(self.g, "wt")
        nx.draw_networkx_edge_labels(self.g, pos, edge_labels=edge_labels)
        plt.show()
    
    def visualizepath(self, path):
        edges = []
        
        for i in range(len(path)-1):
            edges.append((path[i], path[i+1]))

        pos = nx.kamada_kawai_layout(self.g)
        nx.draw(self.g, pos=pos, with_labels=True, node_size=500, alpha=0.8)
        nx.draw_networkx_nodes(self.g, pos=pos, nodelist=path, node_color='g')
        nx.draw_networkx_edges(self.g, pos, edgelist=edges, width=3, edge_color='b', alpha=1)
        edge_labels = nx.get_edge_attributes(self.g, "wt")
        nx.draw_networkx_edge_labels(self.g, pos, edge_labels=edge_labels)
        plt.show()

# %%
class PQueue:
    def __init__(self):
        self.queue = []
        
    def isEmpty(self):
        return len(self.queue) == 0
    
    def enqueue(self, ele, pri):
        self.queue.append((ele, pri))
    
    def dequeuemin(self):
        if self.isEmpty():
            return None, None
        
        self.queue.sort(key=lambda x:x[1])
        
        ele, pri = self.queue.pop(0)
        
        return ele, pri
    
    def dequeuemax(self):
        if self.isEmpty():
            return None, None
        
        self.queue.sort(key=lambda x:x[1])
        
        ele, pri = self.queue.pop(-1)
        
        return ele, pri

# %%
def astar(graph, heuristic, start, goal):
    q = PQueue()
    q.enqueue((start, [start]), heuristic[start])
    
    while not q.isEmpty():
        ele, pri = q.dequeuemin()
        
        if ele == None:
            return None
        
        node, path = ele
        
        if node in goal:
            return path
        
        cost_node = pri - heuristic[node]
        
        for neighbour in graph.adjlist[node]:
            if neighbour not in path:
                new_cost = cost_node + graph.adjlist[node][neighbour] + heuristic[neighbour]
                new_path = path[:]
                new_path.append(neighbour)
                q.enqueue((neighbour, new_path), new_cost)
    
    return None, None

# %%
edges = int(input('Enter the number of edges in the graph: '))

g = Graph()

print('Enter the edges of the graph in the format (u, v, weight): ')

for _ in range(edges):
    u, v, w = tuple(input().split(' '))
    w = int(w)
    g.addedge(u, v, w)
    
g.visualize()
# Out:
# Enter the number of edges in the graph: 14
# Enter the edges of the graph in the format (u, v, weight):
# A B 6
# A F 3
# B D 2
# B C 3
# C E 5
# C D 1
# D E 8
# E J 5
# E I 5
# J I 3
# G I 3
# G F 1
# I H 2
# F H 7

# %%
start = 'A'
goal = 'J'
heu = {
        'A': 10,
        'B': 8,
        'C': 5,
        'D': 7,
        'E': 8,
        'F': 6,
        'G': 5,
        'H': 3,
        'I': 1,
        'J': 0
    }

path = astar(g, heu, start, [goal])

# %%
if path == None:
    print('Path to goal does not exist')
else:
    print(f'Path from {start} to {goal} is: {path}')
    g.visualizepath(path)
# Out:
# Path from A to J is: ['A', 'F', 'G', 'I', 'J']
